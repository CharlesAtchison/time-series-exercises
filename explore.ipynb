# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from acquire import *

# %%
# plotting defaults
plt.rc('figure', figsize=(13, 7))
plt.style.use('seaborn-whitegrid')
plt.rc('font', size=16)

# %%
sales_df = pd.read_csv('sales_data.csv', index_col=[0]).set_index('sale_date').sort_index()
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sales_df
# Out:
#                                item_id  sale_amount  sale_id  store_id  \
# sale_date
# Fri, 01 Apr 2016 00:00:00 GMT       38         88.0   691415         9
# Fri, 01 Apr 2016 00:00:00 GMT       50         60.0   905057         6
# Fri, 01 Apr 2016 00:00:00 GMT       35         83.0   625679         3
# Fri, 01 Apr 2016 00:00:00 GMT       15        132.0   269609         8
# Fri, 01 Apr 2016 00:00:00 GMT        7         66.0   110747         1
# ...                                ...          ...      ...       ...
# Wed, 31 May 2017 00:00:00 GMT       45         86.0   810530         4
# Wed, 31 May 2017 00:00:00 GMT       31         76.0   562194         8
# Wed, 31 May 2017 00:00:00 GMT        6         68.0   100216         5
# Wed, 31 May 2017 00:00:00 GMT       26         57.0   461764         3
# Wed, 31 May 2017 00:00:00 GMT       15        115.0   262730         4
#
#                                          store_address   store_city  \
# sale_date
# Fri, 01 Apr 2016 00:00:00 GMT       735 SW Military Dr  San Antonio
# Fri, 01 Apr 2016 00:00:00 GMT       1015 S WW White Rd  San Antonio
# Fri, 01 Apr 2016 00:00:00 GMT  2118 Fredericksburg Rdj  San Antonio
# Fri, 01 Apr 2016 00:00:00 GMT      15000 San Pedro Ave  San Antonio
# Fri, 01 Apr 2016 00:00:00 GMT   12125 Alamo Ranch Pkwy  San Antonio
# ...                                                ...          ...
# Wed, 31 May 2017 00:00:00 GMT          516 S Flores St  San Antonio
# Wed, 31 May 2017 00:00:00 GMT      15000 San Pedro Ave  San Antonio
# Wed, 31 May 2017 00:00:00 GMT          1520 Austin Hwy  San Antonio
# Wed, 31 May 2017 00:00:00 GMT  2118 Fredericksburg Rdj  San Antonio
# Wed, 31 May 2017 00:00:00 GMT          516 S Flores St  San Antonio
#
#                               store_state  store_zipcode          item_brand  \
# sale_date
# Fri, 01 Apr 2016 00:00:00 GMT          TX          78221                 NaN
# Fri, 01 Apr 2016 00:00:00 GMT          TX          78220                 NaN
# Fri, 01 Apr 2016 00:00:00 GMT          TX          78201                 NaN
# Fri, 01 Apr 2016 00:00:00 GMT          TX          78232               Suave
# Fri, 01 Apr 2016 00:00:00 GMT          TX          78253  Twinings Of London
# ...                                   ...            ...                 ...
# Wed, 31 May 2017 00:00:00 GMT          TX          78204                 NaN
# Wed, 31 May 2017 00:00:00 GMT          TX          78232                 NaN
# Wed, 31 May 2017 00:00:00 GMT          TX          78218        Sally Hansen
# Wed, 31 May 2017 00:00:00 GMT          TX          78201                 NaN
# Wed, 31 May 2017 00:00:00 GMT          TX          78204               Suave
#
#                                                                        item_name  \
# sale_date
# Fri, 01 Apr 2016 00:00:00 GMT                                                NaN
# Fri, 01 Apr 2016 00:00:00 GMT                                                NaN
# Fri, 01 Apr 2016 00:00:00 GMT                                                NaN
# Fri, 01 Apr 2016 00:00:00 GMT  Suave Naturals Moisturizing Body Wash Creamy T...
# Fri, 01 Apr 2016 00:00:00 GMT  Twinings Of London Classics Lady Grey Tea - 20 Ct
# ...                                                                          ...
# Wed, 31 May 2017 00:00:00 GMT                                                NaN
# Wed, 31 May 2017 00:00:00 GMT                                                NaN
# Wed, 31 May 2017 00:00:00 GMT  Sally Hansen Nail Color Magnetic 903 Silver El...
# Wed, 31 May 2017 00:00:00 GMT                                                NaN
# Wed, 31 May 2017 00:00:00 GMT  Suave Naturals Moisturizing Body Wash Creamy T...
#
#                                item_price    item_upc12    item_upc14
# sale_date
# Fri, 01 Apr 2016 00:00:00 GMT         NaN           NaN           NaN
# Fri, 01 Apr 2016 00:00:00 GMT         NaN           NaN           NaN
# Fri, 01 Apr 2016 00:00:00 GMT         NaN           NaN           NaN
# Fri, 01 Apr 2016 00:00:00 GMT        9.11  7.940085e+10  7.940085e+10
# Fri, 01 Apr 2016 00:00:00 GMT        9.64  7.017715e+10  7.017715e+10
# ...                                   ...           ...           ...
# Wed, 31 May 2017 00:00:00 GMT         NaN           NaN           NaN
# Wed, 31 May 2017 00:00:00 GMT         NaN           NaN           NaN
# Wed, 31 May 2017 00:00:00 GMT        6.93  7.417039e+10  7.417039e+10
# Wed, 31 May 2017 00:00:00 GMT         NaN           NaN           NaN
# Wed, 31 May 2017 00:00:00 GMT        9.11  7.940085e+10  7.940085e+10
#
# [913000 rows x 13 columns]
